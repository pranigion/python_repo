# %%
print("hello")
# Out:
# Running cells with '.venv (Python 3.11.0)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/upf3kor/Desktop/Python_advanced/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# Some basic functions for data engineering

a = "prashant"
print(a.lower())
print(a.upper())

b = "Ansh lamba data engineer"
my_list = b.split()
print(my_list)

file = "data_flight.csv"

if file.endswith('.csv'):
    print('CSV file present')
elif file.startswith('data'):
    print('raw data file')

statement ="prashant what are you doing , prashant hope you are good"
print(statement.count('prashant'))


demo_str = "Hello"
demo_var = "10"
demo_var1=10
demo_var2 ="123abc"
